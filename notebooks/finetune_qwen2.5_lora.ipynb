# %% [markdown]
# # Fine-Tuning Qwen2.5-1.5B with LoRA
#
# Instruction-tune the **base** Qwen2.5-1.5B with LoRA on Alpaca, then compare it
# to the base model. Runs in ~30 min on a Colab **A100/L4** (use `--load-4bit` on a free T4).
#
# **Runtime → Change runtime type → GPU** before running.

# %%
# !nvidia-smi

# %%
# 1. Get the code and install dependencies
# !git clone https://github.com/mlahozy21/Fine-Tuning-Qwen2.5-with-LoRA.git
# %cd Fine-Tuning-Qwen2.5-with-LoRA
# !pip install -q -r requirements.txt

# %%
# 2. Train the LoRA adapter (fast run: 3k examples, 1 epoch)
# !python src/finetune_lora.py --max-samples 3000 --epochs 1

# %%
# 3. Compare base vs fine-tuned
# !python src/compare.py --adapter outputs/qwen2.5-1.5b-lora
